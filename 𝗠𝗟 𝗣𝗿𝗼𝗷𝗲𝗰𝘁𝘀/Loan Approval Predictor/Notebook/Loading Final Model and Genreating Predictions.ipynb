# %%
import pickle

# %%
with open(r"C:\Users\shobh\Downloads\AI and DATA SCIENCE\𝗠𝗟 𝗣𝗿𝗼𝗷𝗲𝗰𝘁𝘀\Loan Approval Predictor\Model\load approval predictor.pkl", "rb") as file:
    model = pickle.load(file)

with open(r"C:\Users\shobh\Downloads\AI and DATA SCIENCE\𝗠𝗟 𝗣𝗿𝗼𝗷𝗲𝗰𝘁𝘀\Loan Approval Predictor\Model\load approval scaler.pkl", "rb") as file:
    scaler = pickle.load(file)

# %%
# inputs 

dependents = int(input("Number of Dependents: "))
education = int(input("Education (0=Graduate, 1=Not Graduate): "))
self_employed = int(input("Self Employed (0=No, 1=Yes): "))
income = int(input("Annual Income: "))
loan_amount = int(input("Loan Amount: "))
loan_term = int(input("Loan Term: "))
cibil_score = int(input("CIBIL Score: "))
residential_assets = int(input("Residential Assets Value: "))
commercial_assets = int(input("Commercial Assets Value: "))
luxury_assets = int(input("Luxury Assets Value: "))
bank_assets = int(input("Bank Assets Value: "))


new_customer = [[
    dependents,
    education,
    self_employed,
    income,
    loan_amount,
    loan_term,
    cibil_score,
    residential_assets,
    commercial_assets,
    luxury_assets,
    bank_assets
]]


new_customer_scaled = scaler.transform(new_customer)

prediction = model.predict(new_customer_scaled)

if prediction[0] == 0:
    print("Approved")
else:
    print("Rejected")

# %%
new_customer = [[
    dependents,
    education,
    self_employed,
    income,
    loan_amount,
    loan_term,
    cibil_score,
    residential_assets,
    commercial_assets,
    luxury_assets,
    bank_assets
]]


new_customer_scaled = scaler.transform(new_customer)

prediction = model.predict(new_customer_scaled)

if prediction[0] == 0:
    print("Approved")
else:
    print("Rejected")
# Out:
# Rejected
# C:\Users\shobh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
