# %%
import pandas as pd
import numpy as np

# %%
load_csv = pd.read_csv(r"C:\Users\shobh\Downloads\restaurant_analysis app\real_indian_restaurants_dataset.csv")

df = pd.DataFrame(load_csv)


print(df)
# Out:
#              Restaurant       City  Rating  Price         Cuisine
# 0         Indian Accent  New Delhi     4.7   4000   Modern Indian
# 1               Bukhara  New Delhi     4.5   3500    North Indian
# 2               Karim's  New Delhi     4.2    800         Mughlai
# 3       The Spice Route  New Delhi     4.5   4500           Asian
# 4                  Varq  New Delhi     4.6   5000     Fine Dining
# 5                 Tamra  New Delhi     4.4   3000          Buffet
# 6               Dakshin  New Delhi     4.7   3200    South Indian
# 7         Pind Balluchi  New Delhi     4.2   1500         Punjabi
# 8            Moti Mahal      Delhi     4.3   1200    North Indian
# 9       Saravana Bhavan      Delhi     4.4    700    South Indian
# 10      Britannia & Co.     Mumbai     4.5   1800           Parsi
# 11              Trishna     Mumbai     4.6   3500         Seafood
# 12         Leopold Cafe     Mumbai     4.3   1400            Cafe
# 13             Bademiya     Mumbai     4.4    900           Kebab
# 14            The Table     Mumbai     4.6   4000        European
# 15   Wasabi by Morimoto     Mumbai     4.7   6500        Japanese
# 16          Cafe Madras     Mumbai     4.5    600    South Indian
# 17     Pizza By The Bay     Mumbai     4.4   2000         Italian
# 18               Khyber     Mumbai     4.5   2500    North Indian
# 19              Bastian     Mumbai     4.3   4500         Seafood
# 20                  MTR  Bengaluru     4.6    500    South Indian
# 21     Vidyarthi Bhavan  Bengaluru     4.5    400    South Indian
# 22                 Toit  Bengaluru     4.5   2200         Brewpub
# 23            Karavalli  Bengaluru     4.7   3500         Coastal
# 24                  CTR  Bengaluru     4.6    450    South Indian
# 25       The Only Place  Bengaluru     4.4   1800      Steakhouse
# 26        Meghana Foods  Bengaluru     4.4   1200         Biryani
# 27    Empire Restaurant  Bengaluru     4.2    900   Multi Cuisine
# 28         Corner House  Bengaluru     4.7    350        Desserts
# 29       Airlines Hotel  Bengaluru     4.3    600            Cafe
# 30     Paradise Biryani  Hyderabad     4.3   1200         Biryani
# 31          Shah Ghouse  Hyderabad     4.4    900      Hyderabadi
# 32             Bawarchi  Hyderabad     4.2    800         Biryani
# 33             Chutneys  Hyderabad     4.5   1000    South Indian
# 34       Jewel of Nizam  Hyderabad     4.6   5000     Fine Dining
# 35           Cafe Bahar  Hyderabad     4.3    700         Biryani
# 36          Pista House  Hyderabad     4.4    600          Bakery
# 37  Ohri's Jiva Imperia  Hyderabad     4.5   3000    North Indian
# 38              Exotica  Hyderabad     4.4   2800  Rooftop Dining
# 39  Rayalaseema Ruchulu  Hyderabad     4.3   1100          Andhra
# 40    Murugan Idli Shop    Chennai     4.5    500    South Indian
# 41          Annalakshmi    Chennai     4.6   1200      Vegetarian
# 42           The Marina    Chennai     4.4   1500         Seafood
# 43             Peshawri    Chennai     4.5   3500    North Indian
# 44                  A2B    Chennai     4.3    600    South Indian
# 45      Barbeque Nation    Chennai     4.4   2000          Buffet
# 46       Copper Chimney    Chennai     4.3   1800    North Indian
# 47              Mathsya    Chennai     4.2    900      Vegetarian
# 48             The Farm    Chennai     4.5   2500         Organic
# 49              Dakshin    Chennai     4.7   4000    South Indian
# 50             Kewpie's    Kolkata     4.5   1400         Bengali
# 51              Arsalan    Kolkata     4.4    900         Biryani
# 52            Peter Cat    Kolkata     4.5   1800     Continental
# 53   6 Ballygunge Place    Kolkata     4.6   2200         Bengali
# 54              Mocambo    Kolkata     4.4   1700     Continental
# 55               Flurys    Kolkata     4.5   1200            Cafe
# 56         Oh! Calcutta    Kolkata     4.5   2500         Bengali
# 57             Bohemian    Kolkata     4.6   2000          Fusion
# 58              Bar-B-Q    Kolkata     4.3   1500         Chinese
# 59               Aminia    Kolkata     4.2   1000         Mughlai

# %%
load_csv = pd.read_csv(r"C:\Users\shobh\Downloads\restaurant_analysis app\real_indian_restaurants_dataset.csv")

df = pd.DataFrame(load_csv)


print(df)
# Out:
#              Restaurant       City  Rating  Price         Cuisine
# 0         Indian Accent  New Delhi     4.7   4000   Modern Indian
# 1               Bukhara  New Delhi     4.5   3500    North Indian
# 2               Karim's  New Delhi     4.2    800         Mughlai
# 3       The Spice Route  New Delhi     4.5   4500           Asian
# 4                  Varq  New Delhi     4.6   5000     Fine Dining
# 5                 Tamra  New Delhi     4.4   3000          Buffet
# 6               Dakshin  New Delhi     4.7   3200    South Indian
# 7         Pind Balluchi  New Delhi     4.2   1500         Punjabi
# 8            Moti Mahal      Delhi     4.3   1200    North Indian
# 9       Saravana Bhavan      Delhi     4.4    700    South Indian
# 10      Britannia & Co.     Mumbai     4.5   1800           Parsi
# 11              Trishna     Mumbai     4.6   3500         Seafood
# 12         Leopold Cafe     Mumbai     4.3   1400            Cafe
# 13             Bademiya     Mumbai     4.4    900           Kebab
# 14            The Table     Mumbai     4.6   4000        European
# 15   Wasabi by Morimoto     Mumbai     4.7   6500        Japanese
# 16          Cafe Madras     Mumbai     4.5    600    South Indian
# 17     Pizza By The Bay     Mumbai     4.4   2000         Italian
# 18               Khyber     Mumbai     4.5   2500    North Indian
# 19              Bastian     Mumbai     4.3   4500         Seafood
# 20                  MTR  Bengaluru     4.6    500    South Indian
# 21     Vidyarthi Bhavan  Bengaluru     4.5    400    South Indian
# 22                 Toit  Bengaluru     4.5   2200         Brewpub
# 23            Karavalli  Bengaluru     4.7   3500         Coastal
# 24                  CTR  Bengaluru     4.6    450    South Indian
# 25       The Only Place  Bengaluru     4.4   1800      Steakhouse
# 26        Meghana Foods  Bengaluru     4.4   1200         Biryani
# 27    Empire Restaurant  Bengaluru     4.2    900   Multi Cuisine
# 28         Corner House  Bengaluru     4.7    350        Desserts
# 29       Airlines Hotel  Bengaluru     4.3    600            Cafe
# 30     Paradise Biryani  Hyderabad     4.3   1200         Biryani
# 31          Shah Ghouse  Hyderabad     4.4    900      Hyderabadi
# 32             Bawarchi  Hyderabad     4.2    800         Biryani
# 33             Chutneys  Hyderabad     4.5   1000    South Indian
# 34       Jewel of Nizam  Hyderabad     4.6   5000     Fine Dining
# 35           Cafe Bahar  Hyderabad     4.3    700         Biryani
# 36          Pista House  Hyderabad     4.4    600          Bakery
# 37  Ohri's Jiva Imperia  Hyderabad     4.5   3000    North Indian
# 38              Exotica  Hyderabad     4.4   2800  Rooftop Dining
# 39  Rayalaseema Ruchulu  Hyderabad     4.3   1100          Andhra
# 40    Murugan Idli Shop    Chennai     4.5    500    South Indian
# 41          Annalakshmi    Chennai     4.6   1200      Vegetarian
# 42           The Marina    Chennai     4.4   1500         Seafood
# 43             Peshawri    Chennai     4.5   3500    North Indian
# 44                  A2B    Chennai     4.3    600    South Indian
# 45      Barbeque Nation    Chennai     4.4   2000          Buffet
# 46       Copper Chimney    Chennai     4.3   1800    North Indian
# 47              Mathsya    Chennai     4.2    900      Vegetarian
# 48             The Farm    Chennai     4.5   2500         Organic
# 49              Dakshin    Chennai     4.7   4000    South Indian
# 50             Kewpie's    Kolkata     4.5   1400         Bengali
# 51              Arsalan    Kolkata     4.4    900         Biryani
# 52            Peter Cat    Kolkata     4.5   1800     Continental
# 53   6 Ballygunge Place    Kolkata     4.6   2200         Bengali
# 54              Mocambo    Kolkata     4.4   1700     Continental
# 55               Flurys    Kolkata     4.5   1200            Cafe
# 56         Oh! Calcutta    Kolkata     4.5   2500         Bengali
# 57             Bohemian    Kolkata     4.6   2000          Fusion
# 58              Bar-B-Q    Kolkata     4.3   1500         Chinese
# 59               Aminia    Kolkata     4.2   1000         Mughlai

# %%
fltr = df.sort_values(by="Rating", ascending=True)

fltr.index = range(1, len(fltr) +1)

print(fltr)
# Out:
#              Restaurant       City  Rating  Price         Cuisine
# 1                Aminia    Kolkata     4.2   1000         Mughlai
# 2               Mathsya    Chennai     4.2    900      Vegetarian
# 3               Karim's  New Delhi     4.2    800         Mughlai
# 4         Pind Balluchi  New Delhi     4.2   1500         Punjabi
# 5              Bawarchi  Hyderabad     4.2    800         Biryani
# 6     Empire Restaurant  Bengaluru     4.2    900   Multi Cuisine
# 7        Copper Chimney    Chennai     4.3   1800    North Indian
# 8                   A2B    Chennai     4.3    600    South Indian
# 9   Rayalaseema Ruchulu  Hyderabad     4.3   1100          Andhra
# 10           Cafe Bahar  Hyderabad     4.3    700         Biryani
# 11     Paradise Biryani  Hyderabad     4.3   1200         Biryani
# 12              Bar-B-Q    Kolkata     4.3   1500         Chinese
# 13              Bastian     Mumbai     4.3   4500         Seafood
# 14       Airlines Hotel  Bengaluru     4.3    600            Cafe
# 15         Leopold Cafe     Mumbai     4.3   1400            Cafe
# 16           Moti Mahal      Delhi     4.3   1200    North Indian
# 17          Pista House  Hyderabad     4.4    600          Bakery
# 18           The Marina    Chennai     4.4   1500         Seafood
# 19                Tamra  New Delhi     4.4   3000          Buffet
# 20              Exotica  Hyderabad     4.4   2800  Rooftop Dining
# 21             Bademiya     Mumbai     4.4    900           Kebab
# 22              Arsalan    Kolkata     4.4    900         Biryani
# 23          Shah Ghouse  Hyderabad     4.4    900      Hyderabadi
# 24      Barbeque Nation    Chennai     4.4   2000          Buffet
# 25        Meghana Foods  Bengaluru     4.4   1200         Biryani
# 26      Saravana Bhavan      Delhi     4.4    700    South Indian
# 27              Mocambo    Kolkata     4.4   1700     Continental
# 28     Pizza By The Bay     Mumbai     4.4   2000         Italian
# 29       The Only Place  Bengaluru     4.4   1800      Steakhouse
# 30              Bukhara  New Delhi     4.5   3500    North Indian
# 31             Peshawri    Chennai     4.5   3500    North Indian
# 32             The Farm    Chennai     4.5   2500         Organic
# 33    Murugan Idli Shop    Chennai     4.5    500    South Indian
# 34          Cafe Madras     Mumbai     4.5    600    South Indian
# 35  Ohri's Jiva Imperia  Hyderabad     4.5   3000    North Indian
# 36               Khyber     Mumbai     4.5   2500    North Indian
# 37         Oh! Calcutta    Kolkata     4.5   2500         Bengali
# 38             Chutneys  Hyderabad     4.5   1000    South Indian
# 39     Vidyarthi Bhavan  Bengaluru     4.5    400    South Indian
# 40                 Toit  Bengaluru     4.5   2200         Brewpub
# 41               Flurys    Kolkata     4.5   1200            Cafe
# 42      Britannia & Co.     Mumbai     4.5   1800           Parsi
# 43            Peter Cat    Kolkata     4.5   1800     Continental
# 44             Kewpie's    Kolkata     4.5   1400         Bengali
# 45      The Spice Route  New Delhi     4.5   4500           Asian
# 46             Bohemian    Kolkata     4.6   2000          Fusion
# 47   6 Ballygunge Place    Kolkata     4.6   2200         Bengali
# 48            The Table     Mumbai     4.6   4000        European
# 49          Annalakshmi    Chennai     4.6   1200      Vegetarian
# 50       Jewel of Nizam  Hyderabad     4.6   5000     Fine Dining
# 51              Trishna     Mumbai     4.6   3500         Seafood
# 52                  CTR  Bengaluru     4.6    450    South Indian
# 53                  MTR  Bengaluru     4.6    500    South Indian
# 54                 Varq  New Delhi     4.6   5000     Fine Dining
# 55              Dakshin    Chennai     4.7   4000    South Indian
# 56              Dakshin  New Delhi     4.7   3200    South Indian
# 57         Corner House  Bengaluru     4.7    350        Desserts
# 58            Karavalli  Bengaluru     4.7   3500         Coastal
# 59   Wasabi by Morimoto     Mumbai     4.7   6500        Japanese
# 60        Indian Accent  New Delhi     4.7   4000   Modern Indian

# %%
load_csv = pd.read_csv(r"C:\Users\shobh\Downloads\restaurant_analysis app\real_indian_restaurants_dataset.csv")

df = pd.DataFrame(load_csv)


print(df)
# Out:
#              Restaurant       City  Rating  Price         Cuisine
# 0         Indian Accent  New Delhi     4.7   4000   Modern Indian
# 1               Bukhara  New Delhi     4.5   3500    North Indian
# 2               Karim's  New Delhi     4.2    800         Mughlai
# 3       The Spice Route  New Delhi     4.5   4500           Asian
# 4                  Varq  New Delhi     4.6   5000     Fine Dining
# 5                 Tamra  New Delhi     4.4   3000          Buffet
# 6               Dakshin  New Delhi     4.7   3200    South Indian
# 7         Pind Balluchi  New Delhi     4.2   1500         Punjabi
# 8            Moti Mahal      Delhi     4.3   1200    North Indian
# 9       Saravana Bhavan      Delhi     4.4    700    South Indian
# 10      Britannia & Co.     Mumbai     4.5   1800           Parsi
# 11              Trishna     Mumbai     4.6   3500         Seafood
# 12         Leopold Cafe     Mumbai     4.3   1400            Cafe
# 13             Bademiya     Mumbai     4.4    900           Kebab
# 14            The Table     Mumbai     4.6   4000        European
# 15   Wasabi by Morimoto     Mumbai     4.7   6500        Japanese
# 16          Cafe Madras     Mumbai     4.5    600    South Indian
# 17     Pizza By The Bay     Mumbai     4.4   2000         Italian
# 18               Khyber     Mumbai     4.5   2500    North Indian
# 19              Bastian     Mumbai     4.3   4500         Seafood
# 20                  MTR  Bengaluru     4.6    500    South Indian
# 21     Vidyarthi Bhavan  Bengaluru     4.5    400    South Indian
# 22                 Toit  Bengaluru     4.5   2200         Brewpub
# 23            Karavalli  Bengaluru     4.7   3500         Coastal
# 24                  CTR  Bengaluru     4.6    450    South Indian
# 25       The Only Place  Bengaluru     4.4   1800      Steakhouse
# 26        Meghana Foods  Bengaluru     4.4   1200         Biryani
# 27    Empire Restaurant  Bengaluru     4.2    900   Multi Cuisine
# 28         Corner House  Bengaluru     4.7    350        Desserts
# 29       Airlines Hotel  Bengaluru     4.3    600            Cafe
# 30     Paradise Biryani  Hyderabad     4.3   1200         Biryani
# 31          Shah Ghouse  Hyderabad     4.4    900      Hyderabadi
# 32             Bawarchi  Hyderabad     4.2    800         Biryani
# 33             Chutneys  Hyderabad     4.5   1000    South Indian
# 34       Jewel of Nizam  Hyderabad     4.6   5000     Fine Dining
# 35           Cafe Bahar  Hyderabad     4.3    700         Biryani
# 36          Pista House  Hyderabad     4.4    600          Bakery
# 37  Ohri's Jiva Imperia  Hyderabad     4.5   3000    North Indian
# 38              Exotica  Hyderabad     4.4   2800  Rooftop Dining
# 39  Rayalaseema Ruchulu  Hyderabad     4.3   1100          Andhra
# 40    Murugan Idli Shop    Chennai     4.5    500    South Indian
# 41          Annalakshmi    Chennai     4.6   1200      Vegetarian
# 42           The Marina    Chennai     4.4   1500         Seafood
# 43             Peshawri    Chennai     4.5   3500    North Indian
# 44                  A2B    Chennai     4.3    600    South Indian
# 45      Barbeque Nation    Chennai     4.4   2000          Buffet
# 46       Copper Chimney    Chennai     4.3   1800    North Indian
# 47              Mathsya    Chennai     4.2    900      Vegetarian
# 48             The Farm    Chennai     4.5   2500         Organic
# 49              Dakshin    Chennai     4.7   4000    South Indian
# 50             Kewpie's    Kolkata     4.5   1400         Bengali
# 51              Arsalan    Kolkata     4.4    900         Biryani
# 52            Peter Cat    Kolkata     4.5   1800     Continental
# 53   6 Ballygunge Place    Kolkata     4.6   2200         Bengali
# 54              Mocambo    Kolkata     4.4   1700     Continental
# 55               Flurys    Kolkata     4.5   1200            Cafe
# 56         Oh! Calcutta    Kolkata     4.5   2500         Bengali
# 57             Bohemian    Kolkata     4.6   2000          Fusion
# 58              Bar-B-Q    Kolkata     4.3   1500         Chinese
# 59               Aminia    Kolkata     4.2   1000         Mughlai

# %%
# bud = df.sort_values(by="Price",ascending =False)

# bud.index=range(1,len(bud)+1)

# print(bud)


bud = df.sort_values(by="Price",ascending =True)

bud.index=range(1,len(bud)+1)

print(bud.head(5))
# Out:
#           Restaurant       City  Rating  Price       Cuisine
# 1       Corner House  Bengaluru     4.7    350      Desserts
# 2   Vidyarthi Bhavan  Bengaluru     4.5    400  South Indian
# 3                CTR  Bengaluru     4.6    450  South Indian
# 4                MTR  Bengaluru     4.6    500  South Indian
# 5  Murugan Idli Shop    Chennai     4.5    500  South Indian

# %%
load_csv = pd.read_csv(r"C:\Users\shobh\Downloads\restaurant_analysis app\real_indian_restaurants_dataset.csv")

df = pd.DataFrame(load_csv)


print(df)
# Out:
#              Restaurant       City  Rating  Price         Cuisine
# 0         Indian Accent  New Delhi     4.7   4000   Modern Indian
# 1               Bukhara  New Delhi     4.5   3500    North Indian
# 2               Karim's  New Delhi     4.2    800         Mughlai
# 3       The Spice Route  New Delhi     4.5   4500           Asian
# 4                  Varq  New Delhi     4.6   5000     Fine Dining
# 5                 Tamra  New Delhi     4.4   3000          Buffet
# 6               Dakshin  New Delhi     4.7   3200    South Indian
# 7         Pind Balluchi  New Delhi     4.2   1500         Punjabi
# 8            Moti Mahal      Delhi     4.3   1200    North Indian
# 9       Saravana Bhavan      Delhi     4.4    700    South Indian
# 10      Britannia & Co.     Mumbai     4.5   1800           Parsi
# 11              Trishna     Mumbai     4.6   3500         Seafood
# 12         Leopold Cafe     Mumbai     4.3   1400            Cafe
# 13             Bademiya     Mumbai     4.4    900           Kebab
# 14            The Table     Mumbai     4.6   4000        European
# 15   Wasabi by Morimoto     Mumbai     4.7   6500        Japanese
# 16          Cafe Madras     Mumbai     4.5    600    South Indian
# 17     Pizza By The Bay     Mumbai     4.4   2000         Italian
# 18               Khyber     Mumbai     4.5   2500    North Indian
# 19              Bastian     Mumbai     4.3   4500         Seafood
# 20                  MTR  Bengaluru     4.6    500    South Indian
# 21     Vidyarthi Bhavan  Bengaluru     4.5    400    South Indian
# 22                 Toit  Bengaluru     4.5   2200         Brewpub
# 23            Karavalli  Bengaluru     4.7   3500         Coastal
# 24                  CTR  Bengaluru     4.6    450    South Indian
# 25       The Only Place  Bengaluru     4.4   1800      Steakhouse
# 26        Meghana Foods  Bengaluru     4.4   1200         Biryani
# 27    Empire Restaurant  Bengaluru     4.2    900   Multi Cuisine
# 28         Corner House  Bengaluru     4.7    350        Desserts
# 29       Airlines Hotel  Bengaluru     4.3    600            Cafe
# 30     Paradise Biryani  Hyderabad     4.3   1200         Biryani
# 31          Shah Ghouse  Hyderabad     4.4    900      Hyderabadi
# 32             Bawarchi  Hyderabad     4.2    800         Biryani
# 33             Chutneys  Hyderabad     4.5   1000    South Indian
# 34       Jewel of Nizam  Hyderabad     4.6   5000     Fine Dining
# 35           Cafe Bahar  Hyderabad     4.3    700         Biryani
# 36          Pista House  Hyderabad     4.4    600          Bakery
# 37  Ohri's Jiva Imperia  Hyderabad     4.5   3000    North Indian
# 38              Exotica  Hyderabad     4.4   2800  Rooftop Dining
# 39  Rayalaseema Ruchulu  Hyderabad     4.3   1100          Andhra
# 40    Murugan Idli Shop    Chennai     4.5    500    South Indian
# 41          Annalakshmi    Chennai     4.6   1200      Vegetarian
# 42           The Marina    Chennai     4.4   1500         Seafood
# 43             Peshawri    Chennai     4.5   3500    North Indian
# 44                  A2B    Chennai     4.3    600    South Indian
# 45      Barbeque Nation    Chennai     4.4   2000          Buffet
# 46       Copper Chimney    Chennai     4.3   1800    North Indian
# 47              Mathsya    Chennai     4.2    900      Vegetarian
# 48             The Farm    Chennai     4.5   2500         Organic
# 49              Dakshin    Chennai     4.7   4000    South Indian
# 50             Kewpie's    Kolkata     4.5   1400         Bengali
# 51              Arsalan    Kolkata     4.4    900         Biryani
# 52            Peter Cat    Kolkata     4.5   1800     Continental
# 53   6 Ballygunge Place    Kolkata     4.6   2200         Bengali
# 54              Mocambo    Kolkata     4.4   1700     Continental
# 55               Flurys    Kolkata     4.5   1200            Cafe
# 56         Oh! Calcutta    Kolkata     4.5   2500         Bengali
# 57             Bohemian    Kolkata     4.6   2000          Fusion
# 58              Bar-B-Q    Kolkata     4.3   1500         Chinese
# 59               Aminia    Kolkata     4.2   1000         Mughlai

# %%
res = df[df["City"]=="Kolkata"] [["Restaurant","City","Rating"]]




rated = df.sort_values(by="Rating",ascending=False)


rated.index = range(1,len(rated)+1)

print(rated.head(5))
# Out:
#            Restaurant       City  Rating  Price        Cuisine
# 1       Indian Accent  New Delhi     4.7   4000  Modern Indian
# 2             Dakshin  New Delhi     4.7   3200   South Indian
# 3             Dakshin    Chennai     4.7   4000   South Indian
# 4        Corner House  Bengaluru     4.7    350       Desserts
# 5  Wasabi by Morimoto     Mumbai     4.7   6500       Japanese

# %%
load_csv = pd.read_csv(r"C:\Users\shobh\Downloads\restaurant_analysis app\real_indian_restaurants_dataset.csv")

df = pd.DataFrame(load_csv)


print(df)

# %%
#Average resturnt ratingas 


rated = df.groupby("City")["Rating"].mean().round(1)

print("\n Average Restaurant Rating :\n")
print(rated.to_string())

print("\n")


sort = df.sort_values(by="Price",ascending=False)

sort.index  = range(1, len(sort) +1)

print("Most Expensive Resturant :\n\n ",sort.head(1))



sort = df.sort_values(by="Price",ascending=True)

sort.index  = range(1, len(sort) +1)

print("\n\nMost Cheapest Resturant :\n\n ",sort.head(1))
# Out:
#  Average Restaurant Rating :
#
# City
# Bengaluru    4.5
# Chennai      4.4
# Delhi        4.4
# Hyderabad    4.4
# Kolkata      4.4
# Mumbai       4.5
# New Delhi    4.5
#
#
# Most Expensive Resturant :
#
#              Restaurant    City  Rating  Price   Cuisine
# 1  Wasabi by Morimoto  Mumbai     4.7   6500  Japanese
#
#
# Most Cheapest Resturant :
#
#        Restaurant       City  Rating  Price   Cuisine
# 1  Corner House  Bengaluru     4.7    350  Desserts
